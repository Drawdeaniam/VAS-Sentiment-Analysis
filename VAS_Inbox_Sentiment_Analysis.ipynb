# %% [markdown]
# <a href="https://colab.research.google.com/github/Drawdeaniam/VAS-Sentiment-Analysis/blob/main/VAS_Inbox_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
print ("Hello")
# Out:
# Hello

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud 
import sys
sys.setrecursionlimit(10000)

# %%
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Inbox sms report.csv')
print (df)
# Out:
#                    Time In          From  \
# 0     01-Feb-2022 00:15:48  254757885330
# 1     01-Feb-2022 01:00:18  254714048762
# 2     01-Feb-2022 02:27:51  254748651068
# 3     01-Feb-2022 02:44:56  254743776873
# 4     01-Feb-2022 02:45:58  254795706700
# ...                    ...           ...
# 5213  06-Feb-2022 23:42:35  254798986490
# 5214  06-Feb-2022 23:44:10  254705517306
# 5215  06-Feb-2022 23:55:46  254708364160
# 5216  06-Feb-2022 23:55:51  254740914586
# 5217  06-Feb-2022 23:57:02  254704380937
#
#                                                 Message  \
# 0     ae BABU ni kocha kutoka marich west pokot mung...
# 1      Paul kutoka githu fainaki ni bukina faso vs egpt
# 2     NITAKUFA NA SHOCK NA KUGARUZA AKUNA SHIDA AMTA...
# 3                                                  bima
# 4                                                  bima
# ...                                                 ...
# 5213  Zebedii jack kigs. Mwana arsenali kutoka karim...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np

# %%
subset = df[['Message']]
rawdata = subset[:100]
rawdata
# Out:
#                                               Message
# 0   ae BABU ni kocha kutoka marich west pokot mung...
# 1    Paul kutoka githu fainaki ni bukina faso vs egpt
# 2   NITAKUFA NA SHOCK NA KUGARUZA AKUNA SHIDA AMTA...
# 3                                                bima
# 4                                                bima
# ..                                                ...
# 95  My Son Needed 2000 For Some School Programe ,t...
# 96  Coca cola real magic  Mwende mimi nikikunywa c...
# 97                    Zenka interest is so affordable
# 98  Coca cola real magic  Mwende mimi nikikunywa c...
# 99  Coca cola real magic  Mwende mimi nikikunywa c...
#
# [100 rows x 1 columns]

# %%
rawdata_d = subset[0:100].copy()
rawdata_d["Message"]= rawdata_d["Message"].str.lower()
rawdata_d
# Out:
#                                               Message
# 0   ae babu ni kocha kutoka marich west pokot mung...
# 1    paul kutoka githu fainaki ni bukina faso vs egpt
# 2   nitakufa na shock na kugaruza akuna shida amta...
# 3                                                bima
# 4                                                bima
# ..                                                ...
# 95  my son needed 2000 for some school programe ,t...
# 96  coca cola real magic  mwende mimi nikikunywa c...
# 97                    zenka interest is so affordable
# 98  coca cola real magic  mwende mimi nikikunywa c...
# 99  coca cola real magic  mwende mimi nikikunywa c...
#
# [100 rows x 1 columns]

# %%
from textblob import TextBlob

def getSubjectivity(text):
  return TextBlob (text).sentiment.subjectivity

def getPolarity(text):
  return TextBlob(text).sentiment.polarity

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()

# %%
def sentiment_Vader(Message):
    st=(sid.polarity_scores(Message))
    print("Overall sentiment dictionary is : ", st)
    print("sentence was rated as ", st['neg']*100, "% Negative")
    print("sentence was rated as ", st['neu']*100, "% Neutral")
    print("sentence was rated as ", st['pos']*100, "% Positive")
    print("Sentence overall rated as", end = " ")
   
    # decide sentiment as positive, negative and neutral
    if st['compound'] >= 0.05 :
        print("Positive")
    elif st['compound'] <= -0.05 :
        print("Negative")
    else :
        print("Neutral")

# %%
df = rawdata_d
df['Sentiment_Score'] = df['Message'].apply(lambda x: sentiment_Vader (x))
print (df)
# Out:
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence overall rated as Neutral
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence overall rated as Neutral
# Overall sentiment dictionary is :  {'neg': 0.11, 'neu': 0.89, 'pos': 0.0, 'compound': -0.3818}
# sentence was rated as  11.0 % Negative
# sentence was rated as  89.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence overall rated as Negative
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence overall rated as Neutral
# ...
